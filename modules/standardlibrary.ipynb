# %% [markdown]
# Standard library Overview
# python tandard libarary is a vast collection of modules and packages that come bunded with python providing a wide range of functionalities

# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(14))
print(math.pi)
# Out:
# 3.7416573867739413
# 3.141592653589793
