# %%
import math
math.sqrt(10000000)
# Out:
# 3162.2776601683795

# %%
from math import sqrt,pi
print(sqrt(25458888))
print(pi)
# Out:
# 5045.6801325490305
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4,5,6])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
from math import *
print(sqrt(2))
# Out:
# 1.4142135623730951

# %%
from package.maths import addition
print(addition(2,9))
# Out:
# 11

# %%
# both are same
from package import maths
maths.addition(2,8)
# Out:
# 10

# %%
from package.maths import substruction
print(substruction(25,54))
# Out:
# -29

# %%
from package.subpackages import mul
print(mul.multiple(62,59))
# Out:
# 3658

# %%
from package.subpackages.mul import multiple
print(multiple(65,8955))
# Out:
# 582075
