# %% [markdown]
# Standard library Overview
# python tandard libarary is a vast collection of modules and packages that come bunded with python providing a wide range of functionalities out of box.

# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(14))
print(math.pi)
print(math.cos(90))
print(math.cos(1))
# Out:
# 3.7416573867739413
# 3.141592653589793
# -0.4480736161291701
# 0.5403023058681398

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','mango','banana']))
# Out:
# 3
# apple

# %%
#file and directory access

import os
print(os.getcwd())

#create folder
os.makedirs('test_dic')
# Out:
# d:\data-Analyst\python-learning\modules

# %%
#High level operation on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
#Data Serialization
import json
data = {'name': 'Mohsin', 'age': 26}

#json convert to string
json_str= json.dumps(data)
print(json_str)
print(type(json_str))

#string conert to dict
parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Mohsin", "age": 26}
# <class 'str'>
# {'name': 'Mohsin', 'age': 26}
# <class 'dict'>

# %%
#CSV

import csv
with open('example.csv', mode= 'w', newline= '') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['mohsin', '26'])


with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['mohsin', '26']

# %%
#dateTime

from datetime import datetime, timedelta

now = datetime.now()
print(now)


yesterday = now-timedelta(days=28)
print(yesterday)
# Out:
# 2026-03-28 08:46:20.824785
# 2026-02-28 08:46:20.824785

# %%
#time

import time
print(time.time())
time.sleep(5)
print(time.time())
# Out:
# 1774667912.0769062
# 1774667917.0786533

# %%
#Reguar Expression

import re
pattern = r'\d+'
text = 'there are 123 apples'
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
