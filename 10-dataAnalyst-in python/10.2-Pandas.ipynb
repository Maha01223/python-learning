# %% [markdown]
# Pandas-DataFrame And Series
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
# !pip install pandas

# %%
## Series
## A Pandas Series is a one-dimensional array-like object that can hold any data type. It is similar to a column in a table.

import pandas as pd
data=[1,2,3,4,5]
series=pd.Series(data)
print("Series \n",series)
print(type(series))
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#create a series from dictionary

data ={'a': 1, 'b': 2, 'c': 3}
series_dict = pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = ['a', 'b', 'c']
pd.Series(data, index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
##Dataframe 
#create  a data from a dictionary of list

data ={
    'name': ['krish', 'jon', 'jack'],
    'age': [25, 30, 45],
    'city': ['bangalore', 'new york', 'Mumbai']
}

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     name  age       city
# 0  krish   25  bangalore
# 1    jon   30   new york
# 2   jack   45     Mumbai
# <class 'pandas.core.frame.DataFrame'>

# %%
#create a dataframe from a list of dictionaries

data = [
    {'name': "Mohsin", 'age': 32, 'ciy': 'Mumbai'},
    {'name': "Maha", 'age': 31, 'ciy': 'Mumbai'},
    {'name': "Abbas", 'age': 30, 'ciy': 'Mumbai'},
    {'name': "dan", 'age': 34, 'ciy': 'Mumbai'}
]

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      name  age     ciy
# 0  Mohsin   32  Mumbai
# 1    Maha   31  Mumbai
# 2   Abbas   30  Mumbai
# 3     dan   34  Mumbai
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.read_csv('sales_data.csv')
#print(df.head(5))
#print(df.tail(5))
#print(df)
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
#Accessing data from Dataframe
data ={
    'name': ['krish', 'jon', 'jack'],
    'age': [25, 30, 45],
    'city': ['bangalore', 'new york', 'Mumbai']
}

df = pd.DataFrame(data)
print(df)
# Out:
#     name  age       city
# 0  krish   25  bangalore
# 1    jon   30   new york
# 2   jack   45     Mumbai

# %%
print(type(df['name']))
print(df['name'])
# Out:
# <class 'pandas.core.series.Series'>
# 0    krish
# 1      jon
# 2     jack
# Name: name, dtype: object

# %%
df.loc[0]
# Out:
# name        krish
# age            25
# city    bangalore
# Name: 0, dtype: object

# %%
df.iloc[1][2]
# Out:
# C:\Users\maha0\AppData\Local\Temp\ipykernel_16672\65333983.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[1][2]
# 'new york'

# %%
df
# Out:
#     name  age       city
# 0  krish   25  bangalore
# 1    jon   30   new york
# 2   jack   45     Mumbai

# %%
#Accessing a special element
df['name']
df.at[1,'age']
df.at[2,'city']
# Out:
# 'Mumbai'

# %%
##Accesssing a specified element using iat
#The primary difference between .at and .iat in pandas is how they access data: .at uses row/column labels, while .iat uses integer positions (0-based indexing).
df.iat[2,1]
# Out:
# 45

# %%
df
# Out:
#     name  age       city
# 0  krish   25  bangalore
# 1    jon   30   new york
# 2   jack   45     Mumbai

# %%
#data Manupulaion with dataframe
print(df)
# Out:
#     name  age       city
# 0  krish   25  bangalore
# 1    jon   30   new york
# 2   jack   45     Mumbai

# %%
#adding a column
df['salary']= [50000, 60000, 70000]
print(df)
# Out:
#     name  age       city  salary
# 0  krish   25  bangalore   50000
# 1    jon   30   new york   60000
# 2   jack   45     Mumbai   70000

# %%
#remove a column 
df.drop('salary', axis=1,inplace=True)
print(df)
# Out:
#     name  age       city
# 0  krish   25  bangalore
# 1    jon   30   new york
# 2   jack   45     Mumbai

# %%
print(df)
# Out:
#     name  age       city
# 0  krish   25  bangalore
# 1    jon   30   new york
# 2   jack   45     Mumbai

# %%
#adding to age of the column
df['age'] = df['age']+1
print(df)
# Out:
#     name  age       city
# 0  krish   26  bangalore
# 1    jon   31   new york
# 2   jack   46     Mumbai

# %%
df.drop(1, inplace=True)

# %%
df
# Out:
#     name  age       city
# 0  krish   26  bangalore
# 2   jack   46     Mumbai

# %%
df = pd.read_csv('sales_data.csv')
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
#display the data type of each column
print("data types: \n", df.dtypes)
# Out:
# data types:
#  Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# dtype: object

# %%
#describe the dataframe
print("statical summary\n", df.describe())
# Out:
# statical summary
#         Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000
