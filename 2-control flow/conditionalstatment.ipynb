# %% [markdown]
# Condition Statement. { if, elif, else}
# If statement,
# else statement,
# elif statement,
# Nested Conditional Statement,
# Practical example,
# Common error and Best Practice

# %%
#If Statement (if the condition is true then its print)
age = 25
if age>=25:
    print("you are allow to vote in the elecion")
# Out:
# you are allow to vote in the elecion

# %%
#else
# the else statement execute a  block of code
#if the condition in the if statement is false 

age =15

if age>=18:
    print("you are eligible for voting")
else:
    print("you are a Minor")
# Out:
# you are a Minor

# %%
#elif Statement
#the elif satement allows you to check multiple condition, it stand for (else if).

age = 20

if age < 13:
    print("you are child")
elif age < 18:
    print("you are a teenager")
else:
    print("you area an aduts")
# Out:
# you area an aduts

# %%
#Nested Conditiona Statement
#you can place one or more if, elif, or else Statement  to Create Nested Conditional Statement
#If number even, odd, negative

num = int(input("Enter the number"))

if num>0:
    print("number is positive")
    if num%2==0:
        print("number is even")
    else:
        print("number is odd")
else:
    print("number is negtive or zero ")
# Out:
# number is negtive or zero

# %%
#Practical example

#Determine if a year is a leap year using neted condition statement

year = int(input("Enter the year"))

if year%4==0:
    if year%100==0:
        if year%400==0:
            print("year is a leap year")
        else:
            print("year is not a leap year")
    else:
        print("year is a leap year")
else:
    print("year is not a leap year")
# Out:
# year is not a leap year
